# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def rename_metrics(df):
    df['metric'] = df['metric'].map({"correlation":"$CE_{av}$",
                     "nrmse dc": "$NRMSE_{av}$",
                     "rae dc": "$REE_{av}$"})
    return df

# %%
results = pd.read_csv("/Users/b1017579/Documents/PhD/Projects/14-temporal-granularity/temporal_granularity/reports/data/long_term_method_comparison/long_term_method_comparison.csv")
results = rename_metrics(results)
results
# Out:
#             metric      value  year     method  n_clusters
# 0              NaN   0.093694  2008    medoids           1
# 1     $NRMSE_{av}$  12.691766  2008    medoids           1
# 2       $REE_{av}$   6.289713  2008    medoids           1
# 3              NaN   0.099057  2009    medoids           1
# 4     $NRMSE_{av}$  12.601846  2009    medoids           1
# 5       $REE_{av}$   6.899276  2009    medoids           1
# 6              NaN   0.101874  2010    medoids           1
# 7     $NRMSE_{av}$  12.474762  2010    medoids           1
# 8       $REE_{av}$   8.497259  2010    medoids           1
# 9              NaN   0.097426  2011    medoids           1
# 10    $NRMSE_{av}$  13.723136  2011    medoids           1
# 11      $REE_{av}$   9.108368  2011    medoids           1
# 12             NaN   0.099412  2012    medoids           1
# 13    $NRMSE_{av}$  12.971943  2012    medoids           1
# 14      $REE_{av}$   8.103339  2012    medoids           1
# 15             NaN   0.102401  2013    medoids           1
# 16    $NRMSE_{av}$  13.908495  2013    medoids           1
# 17      $REE_{av}$   9.735872  2013    medoids           1
# 18             NaN   0.103156  2014    medoids           1
# 19    $NRMSE_{av}$  15.670035  2014    medoids           1
# 20      $REE_{av}$  12.504288  2014    medoids           1
# 21             NaN   0.111816  2015    medoids           1
# 22    $NRMSE_{av}$  16.960822  2015    medoids           1
# 23      $REE_{av}$  18.116339  2015    medoids           1
# 24             NaN   0.114665  2016    medoids           1
# 25    $NRMSE_{av}$  16.123837  2016    medoids           1
# 26      $REE_{av}$  16.804441  2016    medoids           1
# 27             NaN   0.067399  2008    medoids           2
# 28    $NRMSE_{av}$   5.634647  2008    medoids           2
# 29      $REE_{av}$   3.654059  2008    medoids           2
# ...            ...        ...   ...        ...         ...
# 4290           NaN   0.015260  2016  centroids          48
# 4291  $NRMSE_{av}$   8.309378  2016  centroids          48
# 4292    $REE_{av}$  18.649850  2016  centroids          48
# 4293           NaN   0.004170  2008  centroids          61
# 4294  $NRMSE_{av}$   1.503576  2008  centroids          61
# 4295    $REE_{av}$   2.617656  2008  centroids          61
# 4296           NaN   0.001211  2009  centroids          61
# 4297  $NRMSE_{av}$   3.422065  2009  centroids          61
# 4298    $REE_{av}$   6.553027  2009  centroids          61
# 4299           NaN   0.009760  2010  centroids          61
# 4300  $NRMSE_{av}$   5.103372  2010  centroids          61
# 4301    $REE_{av}$  13.048491  2010  centroids          61
# 4302           NaN   0.003149  2011  centroids          61
# 4303  $NRMSE_{av}$   3.948541  2011  centroids          61
# 4304    $REE_{av}$   7.274027  2011  centroids          61
# 4305           NaN   0.003722  2012  centroids          61
# 4306  $NRMSE_{av}$   4.953313  2012  centroids          61
# 4307    $REE_{av}$  10.793018  2012  centroids          61
# 4308           NaN   0.004910  2013  centroids          61
# 4309  $NRMSE_{av}$   4.018954  2013  centroids          61
# 4310    $REE_{av}$   7.769142  2013  centroids          61
# 4311           NaN   0.007151  2014  centroids          61
# 4312  $NRMSE_{av}$   6.724099  2014  centroids          61
# 4313    $REE_{av}$  13.116374  2014  centroids          61
# 4314           NaN   0.014258  2015  centroids          61
# 4315  $NRMSE_{av}$   7.704680  2015  centroids          61
# 4316    $REE_{av}$  16.121162  2015  centroids          61
# 4317           NaN   0.016800  2016  centroids          61
# 4318  $NRMSE_{av}$   8.914635  2016  centroids          61
# 4319    $REE_{av}$  20.355799  2016  centroids          61
#
# [4320 rows x 5 columns]

# %%
g = sns.FacetGrid(data=results[results.method=="medoids"], col="year", hue="metric", col_wrap=3, margin_titles=True, legend_out=True)
g.map(sns.lineplot, "n_clusters", 'value')
g.add_legend()
# g = g.map(sns.lineplot, x="n_clusters", y="value", hue="metric", marker=".")

# %%
results.head()
# Out:
#          metric      value  year   method  n_clusters
# 0           NaN   0.093694  2008  medoids           1
# 1  $NRMSE_{av}$  12.691766  2008  medoids           1
# 2    $REE_{av}$   6.289713  2008  medoids           1
# 3           NaN   0.099057  2009  medoids           1
# 4  $NRMSE_{av}$  12.601846  2009  medoids           1

# %%
mean_error_results = results.groupby(['metric','n_clusters','method']).value.mean()
mean_error_results = pd.DataFrame(mean_error_results)
mean_error_results.reset_index(inplace=True)
mean_error_results
# Out:
#           metric  n_clusters     method      value
# 0   $NRMSE_{av}$           1  centroids  14.194213
# 1   $NRMSE_{av}$           1    medoids  14.125182
# 2   $NRMSE_{av}$           2  centroids   8.497037
# 3   $NRMSE_{av}$           2    medoids   8.055784
# 4   $NRMSE_{av}$           4  centroids   6.029504
# 5   $NRMSE_{av}$           4    medoids   5.969008
# 6   $NRMSE_{av}$           8  centroids   5.389896
# 7   $NRMSE_{av}$           8    medoids   5.458360
# 8   $NRMSE_{av}$          16  centroids   5.045763
# 9   $NRMSE_{av}$          16    medoids   5.167295
# 10  $NRMSE_{av}$          32  centroids   5.088266
# 11  $NRMSE_{av}$          32    medoids   5.074258
# 12  $NRMSE_{av}$          48  centroids   4.951553
# 13  $NRMSE_{av}$          48    medoids   5.088149
# 14  $NRMSE_{av}$          61  centroids   5.131082
# 15  $NRMSE_{av}$          61    medoids   5.091259
# 16    $REE_{av}$           1  centroids   9.956003
# 17    $REE_{av}$           1    medoids  10.673211
# 18    $REE_{av}$           2  centroids   9.998062
# 19    $REE_{av}$           2    medoids   9.563331
# 20    $REE_{av}$           4  centroids  10.157075
# 21    $REE_{av}$           4    medoids   9.785017
# 22    $REE_{av}$           8  centroids  10.497979
# 23    $REE_{av}$           8    medoids  10.737176
# 24    $REE_{av}$          16  centroids  10.294245
# 25    $REE_{av}$          16    medoids  10.424894
# 26    $REE_{av}$          32  centroids  10.941226
# 27    $REE_{av}$          32    medoids  10.631557
# 28    $REE_{av}$          48  centroids  10.480387
# 29    $REE_{av}$          48    medoids  11.013315
# 30    $REE_{av}$          61  centroids  11.140727
# 31    $REE_{av}$          61    medoids  10.980017

# %%
sns.lineplot(data=mean_error_results, x="n_clusters", y="value", hue='metric')

# %%
g = sns.FacetGrid(data=results[results.method=="centroids"], col="year", hue="metric", col_wrap=3, margin_titles=True, legend_out=True)
g.map(sns.lineplot, "n_clusters", 'value')
g.add_legend()

# %%
original_year = results[results.year==2006]
original_year['method'] = original_year['method']+"_original"
original_year.head()
# mean_error_results.head()
# Out:
# Empty DataFrame
# Columns: [metric, value, year, method, n_clusters]
# Index: []

# %%
mean_error_results = mean_error_results.append(original_year.drop(columns="year"))

# %%
mean_error_results = mean_error_results.rename(columns={"metric":"Metric", "method":"Method"})
mean_error_results['Method'] = mean_error_results['Method'].map({'centroids':'Centroids', 'medoids':"Medoids"})
sns.set(font_scale=1.5)
sns.set_style("whitegrid")
g = sns.catplot(data=mean_error_results, kind="point", x="n_clusters", y="value", hue="Method", col="Metric", sharey=False)
g.set(ylim=(0))
g.set(xlabel='Number of clusters', ylabel='Value')
g.savefig('/Users/b1017579/Documents/PhD/Projects/14-temporal-granularity/temporal_granularity/reports/figures/clusters_compared.pdf')

# %%
results_half = pd.read_csv('/Users/b1017579/Documents/PhD/Projects/14-temporal-granularity/temporal_granularity/reports/data/long_term_method_comparison/long_term_method_comparison_half_years.csv')
results_half = rename_metrics(results_half)
results_half['method'] = results_half['method'] + "_half"
mean_results_with_half = mean_error_results.append(results_half)
mean_results_with_half
# Out:
#          Method        Metric          method        metric  n_clusters  \
# 0     Centroids  $NRMSE_{av}$             NaN           NaN           1
# 1       Medoids  $NRMSE_{av}$             NaN           NaN           1
# 2     Centroids  $NRMSE_{av}$             NaN           NaN           2
# 3       Medoids  $NRMSE_{av}$             NaN           NaN           2
# 4     Centroids  $NRMSE_{av}$             NaN           NaN           4
# 5       Medoids  $NRMSE_{av}$             NaN           NaN           4
# 6     Centroids  $NRMSE_{av}$             NaN           NaN           8
# 7       Medoids  $NRMSE_{av}$             NaN           NaN           8
# 8     Centroids  $NRMSE_{av}$             NaN           NaN          16
# 9       Medoids  $NRMSE_{av}$             NaN           NaN          16
# 10    Centroids  $NRMSE_{av}$             NaN           NaN          32
# 11      Medoids  $NRMSE_{av}$             NaN           NaN          32
# 12    Centroids  $NRMSE_{av}$             NaN           NaN          48
# 13      Medoids  $NRMSE_{av}$             NaN           NaN          48
# 14    Centroids  $NRMSE_{av}$             NaN           NaN          61
# 15      Medoids  $NRMSE_{av}$             NaN           NaN          61
# 16    Centroids    $REE_{av}$             NaN           NaN           1
# 17      Medoids    $REE_{av}$             NaN           NaN           1
# 18    Centroids    $REE_{av}$             NaN           NaN           2
# 19      Medoids    $REE_{av}$             NaN           NaN           2
# 20    Centroids    $REE_{av}$             NaN           NaN           4
# 21      Medoids    $REE_{av}$             NaN           NaN           4
# 22    Centroids    $REE_{av}$             NaN           NaN           8
# 23      Medoids    $REE_{av}$             NaN           NaN           8
# 24    Centroids    $REE_{av}$             NaN           NaN          16
# 25      Medoids    $REE_{av}$             NaN           NaN          16
# 26    Centroids    $REE_{av}$             NaN           NaN          32
# 27      Medoids    $REE_{av}$             NaN           NaN          32
# 28    Centroids    $REE_{av}$             NaN           NaN          48
# 29      Medoids    $REE_{av}$             NaN           NaN          48
# ...         ...           ...             ...           ...         ...
# 2370        NaN           NaN  centroids_half           NaN          48
# 2371        NaN           NaN  centroids_half  $NRMSE_{av}$          48
# 2372        NaN           NaN  centroids_half    $REE_{av}$          48
# 2373        NaN           NaN  centroids_half           NaN          48
# 2374        NaN           NaN  centroids_half  $NRMSE_{av}$          48
# 2375        NaN           NaN  centroids_half    $REE_{av}$          48
# 2376        NaN           NaN  centroids_half           NaN          48
# 2377        NaN           NaN  centroids_half  $NRMSE_{av}$          48
# 2378        NaN           NaN  centroids_half    $REE_{av}$          48
# 2379        NaN           NaN  centroids_half           NaN          48
# 2380        NaN           NaN  centroids_half  $NRMSE_{av}$          48
# 2381        NaN           NaN  centroids_half    $REE_{av}$          48
# 2382        NaN           NaN  centroids_half           NaN          48
# 2383        NaN           NaN  centroids_half  $NRMSE_{av}$          48
# 2384        NaN           NaN  centroids_half    $REE_{av}$          48
# 2385        NaN           NaN  centroids_half           NaN          61
# 2386        NaN           NaN  centroids_half  $NRMSE_{av}$          61
# 2387        NaN           NaN  centroids_half    $REE_{av}$          61
# 2388        NaN           NaN  centroids_half           NaN          61
# 2389        NaN           NaN  centroids_half  $NRMSE_{av}$          61
# 2390        NaN           NaN  centroids_half    $REE_{av}$          61
# 2391        NaN           NaN  centroids_half           NaN          61
# 2392        NaN           NaN  centroids_half  $NRMSE_{av}$          61
# 2393        NaN           NaN  centroids_half    $REE_{av}$          61
# 2394        NaN           NaN  centroids_half           NaN          61
# 2395        NaN           NaN  centroids_half  $NRMSE_{av}$          61
# 2396        NaN           NaN  centroids_half    $REE_{av}$          61
# 2397        NaN           NaN  centroids_half           NaN          61
# 2398        NaN           NaN  centroids_half  $NRMSE_{av}$          61
# 2399        NaN           NaN  centroids_half    $REE_{av}$          61
#
#           value    year
# 0     14.194213     NaN
# 1     14.125182     NaN
# 2      8.497037     NaN
# 3      8.055784     NaN
# 4      6.029504     NaN
# 5      5.969008     NaN
# 6      5.389896     NaN
# 7      5.458360     NaN
# 8      5.045763     NaN
# 9      5.167295     NaN
# 10     5.088266     NaN
# 11     5.074258     NaN
# 12     4.951553     NaN
# 13     5.088149     NaN
# 14     5.131082     NaN
# 15     5.091259     NaN
# 16     9.956003     NaN
# 17    10.673211     NaN
# 18     9.998062     NaN
# 19     9.563331     NaN
# 20    10.157075     NaN
# 21     9.785017     NaN
# 22    10.497979     NaN
# 23    10.737176     NaN
# 24    10.294245     NaN
# 25    10.424894     NaN
# 26    10.941226     NaN
# 27    10.631557     NaN
# 28    10.480387     NaN
# 29    11.013315     NaN
# ...         ...     ...
# 2370   0.001651  2012.0
# 2371   3.265659  2012.0
# 2372   7.824195  2012.0
# 2373   0.006284  2013.0
# 2374   2.654270  2013.0
# 2375   4.766649  2013.0
# 2376   0.003555  2014.0
# 2377   4.930896  2014.0
# 2378   9.744883  2014.0
# 2379   0.015632  2015.0
# 2380   6.399324  2015.0
# 2381  12.977145  2015.0
# 2382   0.014379  2016.0
# 2383   7.083247  2016.0
# 2384  16.100858  2016.0
# 2385   0.003653  2012.0
# 2386   2.691069  2012.0
# 2387   5.435092  2012.0
# 2388   0.011588  2013.0
# 2389   3.162475  2013.0
# 2390   6.357853  2013.0
# 2391   0.005356  2014.0
# 2392   4.968114  2014.0
# 2393   8.145284  2014.0
# 2394   0.020936  2015.0
# 2395   7.059810  2015.0
# 2396  14.978413  2015.0
# 2397   0.019612  2016.0
# 2398   6.572308  2016.0
# 2399  14.389559  2016.0
#
# [2432 rows x 7 columns]

# %%
g = sns.catplot(data=mean_results_with_half, kind="point", x="n_clusters", y="value", hue="method", col="metric", sharey=False)
g.set(ylim=(0))
g.set(xlabel='Number of clusters', ylabel='Value')
