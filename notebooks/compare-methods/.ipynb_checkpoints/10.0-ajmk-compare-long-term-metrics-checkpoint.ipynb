# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
results = pd.read_csv("/Users/b1017579/Documents/PhD/Projects/14-temporal-granularity/temporal_granularity/reports/data/long_term_method_comparison/long_term_method_comparison.csv")
results.head()
# Out:
#         metric      value  year   method  n_clusters
# 0  correlation   0.097521  2006  medoids           1
# 1     nrmse dc  12.688088  2006  medoids           1
# 2       rae dc   3.144228  2006  medoids           1
# 3  correlation   0.097379  2007  medoids           1
# 4     nrmse dc  12.119214  2007  medoids           1

# %%
g = sns.FacetGrid(data=results[results.method=="medoids"], col="year", hue="metric", col_wrap=3, margin_titles=True, legend_out=True)
g.map(sns.lineplot, "n_clusters", 'value')
g.add_legend()
# g = g.map(sns.lineplot, x="n_clusters", y="value", hue="metric", marker=".")

# %%
results.head()
# Out:
#         metric      value  year   method  n_clusters
# 0  correlation   0.097521  2006  medoids           1
# 1     nrmse dc  12.688088  2006  medoids           1
# 2       rae dc   3.144228  2006  medoids           1
# 3  correlation   0.097379  2007  medoids           1
# 4     nrmse dc  12.119214  2007  medoids           1

# %%
mean_error_results = results.groupby(['metric','n_clusters','method']).value.mean()
mean_error_results = pd.DataFrame(mean_error_results)
mean_error_results.reset_index(inplace=True)
mean_error_results
# Out:
#          metric  n_clusters     method      value
# 0   correlation           1  centroids   0.054974
# 1   correlation           1    medoids   0.101673
# 2   correlation           2  centroids   0.067830
# 3   correlation           2    medoids   0.080383
# 4   correlation           4  centroids   0.018733
# 5   correlation           4    medoids   0.015623
# 6   correlation           8  centroids   0.007555
# 7   correlation           8    medoids   0.010097
# 8   correlation          16  centroids   0.008727
# 9   correlation          16    medoids   0.010094
# 10  correlation          32  centroids   0.009462
# 11  correlation          32    medoids   0.008073
# 12  correlation          48  centroids   0.007797
# 13  correlation          48    medoids   0.008871
# 14  correlation          61  centroids   0.008089
# 15  correlation          61    medoids   0.008203
# 16     nrmse dc           1  centroids  14.062517
# 17     nrmse dc           1    medoids  13.812177
# 18     nrmse dc           2  centroids   8.268288
# 19     nrmse dc           2    medoids   8.171719
# 20     nrmse dc           4  centroids   5.695514
# 21     nrmse dc           4    medoids   5.657432
# 22     nrmse dc           8  centroids   4.952654
# 23     nrmse dc           8    medoids   4.855010
# 24     nrmse dc          16  centroids   4.695468
# 25     nrmse dc          16    medoids   4.832613
# 26     nrmse dc          32  centroids   4.559655
# 27     nrmse dc          32    medoids   4.548707
# 28     nrmse dc          48  centroids   4.622738
# 29     nrmse dc          48    medoids   4.767403
# 30     nrmse dc          61  centroids   4.844765
# 31     nrmse dc          61    medoids   4.819678
# 32       rae dc           1  centroids   8.971990
# 33       rae dc           1    medoids   9.337244
# 34       rae dc           2  centroids   9.055237
# 35       rae dc           2    medoids  10.003688
# 36       rae dc           4  centroids   9.328365
# 37       rae dc           4    medoids   8.904142
# 38       rae dc           8  centroids   9.669938
# 39       rae dc           8    medoids   9.255176
# 40       rae dc          16  centroids   9.482300
# 41       rae dc          16    medoids   9.901844
# 42       rae dc          32  centroids   9.278713
# 43       rae dc          32    medoids   9.342467
# 44       rae dc          48  centroids   9.568753
# 45       rae dc          48    medoids  10.143710
# 46       rae dc          61  centroids  10.539085
# 47       rae dc          61    medoids  10.281685

# %%
sns.lineplot(data=mean_error_results, x="n_clusters", y="value", hue='metric')

# %%
g = sns.FacetGrid(data=results[results.method=="centroids"], col="year", hue="metric", col_wrap=3, margin_titles=True, legend_out=True)
g.map(sns.lineplot, "n_clusters", 'value')
g.add_legend()

# %%
original_year = results[results.year==2006].head()
# mean_error_results.head()
# Out:
#          metric      value  year   method  n_clusters
# 0   correlation   0.097521  2006  medoids           1
# 1      nrmse dc  12.688088  2006  medoids           1
# 2        rae dc   3.144228  2006  medoids           1
# 33  correlation   0.076589  2006  medoids           2
# 34     nrmse dc   5.463404  2006  medoids           2

# %%
g = sns.catplot(data=mean_error_results, kind="point", x="n_clusters", y="value", hue="method", col="metric", sharey=False)
g.set(ylim=(0))
